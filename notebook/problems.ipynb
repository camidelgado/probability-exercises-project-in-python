# %% [markdown]
# # Probability exercises

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
#import libraries
import pandas as pd
import numpy as np

#Funtion to roll the dice.

def dice(n):
    rolls = []
    for i in range(n):
        two_dice = np.random.randint(1, 6) + np.random.randint(1, 6)
        rolls.append(two_dice)
    return rolls
times_dice=1000
dice(times_dice)
df=pd.DataFrame(dice(times_dice),columns=['Sum Dice'])
df

sum=[]
for row in df['Sum Dice']:
    if row>7: sum.append(1)
    elif row%2==0:sum.append(1)
    else: sum.append(0)
df['Conditions']=sum
df

print('Percentage of even and/or grater than seven is: ',round(df['Conditions'].sum()/times_dice*100,2),'%')
# Out:
# Percentage of even and/or grater than seven is:  59.2 %

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
#import libraries

d = {}

for i in range(60):
     if i < 10:
        d[i] = 'White'
    elif i > 9 and i < 30:
        d[i] = 'Red'
    else:
        d[i] = 'Green'

# %%
#Initialize important variables

def ballsfromhat():
    balls = {"White":10,
            "Red":20,
            "Green":30}
     
    #Create a new empty dictionary to keep the drawn balls
    drawn = dict.fromkeys(balls.keys(), 0)
     
    toDraw = 5
    for i in range(toDraw):
        rball = np.random.choice(list(balls))
         
        balls[rball] -= 1
        drawn[rball] += 1
         
    return drawn 
 
trials = 1000
match = 0
for i in range(trials):
    r = ballsfromhat()
     
    if (r["White"] ==3 and r["Red"] == 2):
        match += 1
 
print('From', trials, 'runs, we get two red and one white', match, 'times. Probability:', (match/float(trials))*100)

for i in range(trials):
    r = ballsfromhat()
     
    if r["White"] ==3 and r["Red"] == 2:
        match += 1
 
print('From', trials, 'runs, we get two red and one white', match, 'times. Probability:', (match/float(trials))*100)



    
    #make a list of the colors that we choose
    
    

        
    #Convert it to a numpy array
 

    #find the number of each taht we picked
    
    
    
    
    #Keep track if the combination met the criteria
    
    
    
    
#print 'the probability of 3 white and 2 red is' in percentage

#print 'the probability of all the same color is' in percentage
# Out:
# From 1000 runs, we get two red and one white 36 times. Probability: 3.5999999999999996
# From 1000 runs, we get two red and one white 79 times. Probability: 7.9
